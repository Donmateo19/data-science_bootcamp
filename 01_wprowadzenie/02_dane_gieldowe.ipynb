# %% [markdown]
# <a href="https://colab.research.google.com/github/Donmateo19/data-science_bootcamp/blob/main/01_wprowadzenie/02_dane_gieldowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
print(f'numpy: {np.__version__}')
# Out:
# numpy: 1.19.5

# %% [markdown]
# ZAŁADOWANIE DANYCH

# %%
def fetch_financial_data(company='AMZN'):
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')
  #help(pandas_datareader.data.DataReader)


df=fetch_financial_data()
df.info()
df.describe()
#df.head(10)

df.columns = [col.lower() for col in df.columns]
df.columns
type(df.columns)
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2021-10-19 to 2016-10-21
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB
#                  open     high        low    close   volume
# Date
# 2021-10-19  3434.2900  3454.69  3422.0000  3444.15  2386079
# 2021-10-18  3388.3576  3449.17  3385.1000  3446.74  3174115
# 2021-10-15  3311.4200  3410.42  3304.0000  3409.02  5179941
# 2021-10-14  3302.4541  3312.60  3290.7800  3299.86  2112020
# 2021-10-13  3269.7100  3288.38  3261.0889  3284.28  2425086

# %%
df = df.head(10)

x = df[['open','close']]
x
# Out:
#                  open    close
# Date
# 2021-10-19  3434.2900  3444.15
# 2021-10-18  3388.3576  3446.74
# 2021-10-15  3311.4200  3409.02
# 2021-10-14  3302.4541  3299.86
# 2021-10-13  3269.7100  3284.28
# 2021-10-12  3257.0000  3247.33
# 2021-10-11  3275.0000  3246.30
# 2021-10-08  3317.0000  3288.62
# 2021-10-07  3291.5400  3302.43
# 2021-10-06  3213.5300  3262.01

# %% [markdown]
# wycinamy wszystkie wiersze i kolumny 0 i 3 [open i close]

# %%
y = df.iloc[:, :-3]
y
#z = df.loc[:,['open','close']]
#z
# Out:
#                  open       high
# Date
# 2021-10-19  3434.2900  3454.6900
# 2021-10-18  3388.3576  3449.1700
# 2021-10-15  3311.4200  3410.4200
# 2021-10-14  3302.4541  3312.6000
# 2021-10-13  3269.7100  3288.3800
# 2021-10-12  3257.0000  3267.5280
# 2021-10-11  3275.0000  3292.5899
# 2021-10-08  3317.0000  3321.4300
# 2021-10-07  3291.5400  3325.7460
# 2021-10-06  3213.5300  3264.3400

# %%
zz = df.iloc[:3]
zz
# Out:
#                  open     high     low    close   volume
# Date
# 2021-10-19  3434.2900  3454.69  3422.0  3444.15  2386079
# 2021-10-18  3388.3576  3449.17  3385.1  3446.74  3174115
# 2021-10-15  3311.4200  3410.42  3304.0  3409.02  5179941

# %%
zzz = df.loc['2021-10-15']
type(zzz)
# Out:
# pandas.core.frame.DataFrame

# %%
zz.sort_values(by=['Date'], ascending=True)
# Out:
#                  open     high     low    close   volume
# Date
# 2021-10-15  3311.4200  3410.42  3304.0  3409.02  5179941
# 2021-10-18  3388.3576  3449.17  3385.1  3446.74  3174115
# 2021-10-19  3434.2900  3454.69  3422.0  3444.15  2386079

# %%
df = fetch_financial_data('UBER')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 617 entries, 2021-10-19 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    617 non-null    float64
#  1   High    617 non-null    float64
#  2   Low     617 non-null    float64
#  3   Close   617 non-null    float64
#  4   Volume  617 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 28.9 KB

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2021-10-19  47.20  47.69  46.74  47.05  16500199
# 2021-10-18  47.68  47.95  46.75  47.07  19806658
# 2021-10-15  47.91  48.84  47.34  48.36  20581670
# 2021-10-14  46.98  47.94  46.84  47.28  18514016
# 2021-10-13  46.26  47.00  45.94  46.41  13754404

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  617.000000  617.000000  617.000000  617.000000  6.170000e+02
# mean    40.366683   41.138473   39.489081   40.321070  2.348732e+07
# std      9.745332    9.824461    9.604442    9.687885  1.715407e+07
# min     15.960000   17.800000   13.710000   14.820000  3.380003e+06
# 25%     32.440000   33.050000   31.550000   32.530000  1.357918e+07
# 50%     39.350000   40.079900   38.432500   39.520000  1.923841e+07
# 75%     48.280000   49.340000   47.370000   48.120000  2.824445e+07
# max     63.250000   64.050000   60.800000   63.180000  1.863225e+08

# %%
df.head(3)
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2021-10-19  47.20  47.69  46.74  47.05  16500199
# 2021-10-18  47.68  47.95  46.75  47.07  19806658
# 2021-10-15  47.91  48.84  47.34  48.36  20581670

# %%
df['Average'] = (df.Open+df.Close) / 2.0
df.head()
# Out:
#              Open   High    Low  Close    Volume  Average
# Date
# 2021-10-19  47.20  47.69  46.74  47.05  16500199   47.125
# 2021-10-18  47.68  47.95  46.75  47.07  19806658   47.375
# 2021-10-15  47.91  48.84  47.34  48.36  20581670   48.135
# 2021-10-14  46.98  47.94  46.84  47.28  18514016   47.130
# 2021-10-13  46.26  47.00  45.94  46.41  13754404   46.335

# %%
df = df.sort_index()
df.head()
# Out:
#              Open   High    Low  Close     Volume  Average
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240

# %%
df['Close_shift'] = df.Close.shift(1)
df.head()
# Out:
#              Open   High    Low  Close     Volume  Average  Close_shift
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785          NaN
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945        41.57
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135        37.10
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330        39.96
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240        41.29

# %%
df['Daily_Change'] = df.Close / df.Close_shift -1
df.head()
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ...   41.785          NaN           NaN
# 2019-05-13  38.79  39.24  36.08  ...   37.945        41.57     -0.107529
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10      0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96      0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29      0.041414
#
# [5 rows x 8 columns]

# %%
df.head()
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ...   41.785          NaN           NaN
# 2019-05-13  38.79  39.24  36.08  ...   37.945        41.57     -0.107529
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10      0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96      0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29      0.041414
#
# [5 rows x 8 columns]

# %%
zxy = df.iloc[0:5]
for Avg in zxy['Average']:
  print(f"Average= {round(Avg,2)}")
# Out:
# Average= 41.78
# Average= 37.95
# Average= 39.14
# Average= 40.33
# Average= 42.24

# %%
import seaborn as sns
sns.set()
df.Daily_Change.hist(bins=100)

# %%
df.Close.plot()

# %%
df
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ...   41.785          NaN           NaN
# 2019-05-13  38.79  39.24  36.08  ...   37.945        41.57     -0.107529
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10      0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96      0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29      0.041414
# ...           ...    ...    ...  ...      ...          ...           ...
# 2021-10-13  46.26  47.00  45.94  ...   46.335        46.72     -0.006635
# 2021-10-14  46.98  47.94  46.84  ...   47.130        46.41      0.018746
# 2021-10-15  47.91  48.84  47.34  ...   48.135        47.28      0.022843
# 2021-10-18  47.68  47.95  46.75  ...   47.375        48.36     -0.026675
# 2021-10-19  47.20  47.69  46.74  ...   47.125        47.07     -0.000425
#
# [617 rows x 8 columns]

# %%
zxy
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ...   41.785          NaN           NaN
# 2019-05-13  38.79  39.24  36.08  ...   37.945        41.57     -0.107529
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10      0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96      0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29      0.041414
#
# [5 rows x 8 columns]

# %%
df_positive = df[df.Daily_Change > 0]
df_positive

# %%
df_positive.Daily_Change.mean()
# Out:
# 0.02628085604220368

# %%
df_negative = df[df.Daily_Change < 0]

# %%
df_negative.Daily_Change.mean()
# Out:
# -0.023531278321033904

# %%
df_equal = df[df. Close == df.High]

# %%
df_equal
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10      0.077089
# 2019-05-24  41.28  41.51  40.50  ...   41.395        40.47      0.025698
# 2020-08-25  31.04  31.19  30.60  ...   31.115        31.04      0.004832
# 2020-12-04  52.71  54.86  52.71  ...   53.785        52.52      0.044554
# 2021-02-04  56.45  57.85  56.11  ...   57.150        57.12      0.012780
#
# [5 rows x 8 columns]

# %%
df[df.Close == df.Low]
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-08-12  39.84  39.95  37.00  ...   38.420        40.05     -0.076155
# 2019-12-09  27.96  28.36  27.68  ...   27.820        27.86     -0.006461
# 2019-12-27  30.80  31.06  30.17  ...   30.485        30.67     -0.016303
# 2020-12-31  53.28  53.28  51.00  ...   52.140        53.15     -0.040452
#
# [4 rows x 8 columns]

# %%
df[(df.index >= '2020-11-01') & (df.index < '2020-11-15')]

# %%
df[(df.index.month==5) & (df.index.year==2020)]
# Out:
#              Open     High     Low  ...  Average  Close_shift  Daily_Change
# Date                                ...
# 2020-05-01  29.13  29.7200  28.325  ...   28.760        30.27     -0.062108
# 2020-05-04  27.56  28.0700  26.580  ...   27.490        28.39     -0.034167
# 2020-05-05  28.25  28.9088  27.440  ...   28.160        27.42      0.023705
# 2020-05-06  27.50  28.0600  26.810  ...   27.660        28.07     -0.008906
# 2020-05-07  29.60  31.6500  29.580  ...   30.265        27.82      0.111790
# 2020-05-08  32.59  33.3000  31.640  ...   32.690        30.93      0.060136
# 2020-05-11  31.98  32.3850  31.410  ...   31.810        32.79     -0.035072
# 2020-05-12  31.42  34.4500  30.410  ...   31.910        31.64      0.024020
# 2020-05-13  32.30  33.0600  30.830  ...   32.660        32.40      0.019136
# 2020-05-14  32.53  33.0399  31.240  ...   32.660        33.02     -0.006965
# 2020-05-15  32.26  32.8900  31.590  ...   32.365        32.79     -0.009759
# ...
